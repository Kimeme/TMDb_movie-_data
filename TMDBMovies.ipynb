# %% [markdown]
# # Data Analysis Process For TMDB Movies Data From Kaggle

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('C:/Users/archive/tmdb_movies_data.csv')

# %% [markdown]
# 1 Display Top 10 Rows of The Dataset

# %%
data.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
data.head(10)
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
# 5  281957  tt1663202    9.110700  135000000   532950503
# 6   87101  tt1340138    8.654359  155000000   440603537
# 7  286217  tt3659388    7.667400  108000000   595380321
# 8  211672  tt2293640    7.404165   74000000  1156730962
# 9  150540  tt2096673    6.326804  175000000   853708609
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
# 5                  The Revenant
# 6            Terminator Genisys
# 7                   The Martian
# 8                       Minions
# ...

# %% [markdown]
# 2 Check Last 10 Rows of The Dataset

# %%
data.tail(10)
# Out:
#           id    imdb_id  popularity  budget  revenue  \
# 10856  20277  tt0061135    0.140934       0        0
# 10857   5921  tt0060748    0.131378       0        0
# 10858  31918  tt0060921    0.317824       0        0
# 10859  20620  tt0060955    0.089072       0        0
# 10860   5060  tt0060214    0.087034       0        0
# 10861     21  tt0060371    0.080598       0        0
# 10862  20379  tt0060472    0.065543       0        0
# 10863  39768  tt0060161    0.065141       0        0
# 10864  21449  tt0061177    0.064317       0        0
# 10865  22293  tt0060666    0.035919   19000        0
#
#                                          original_title  \
# 10856                                The Ugly Dachshund
# 10857                                      Nevada Smith
# 10858  The Russians Are Coming, The Russians Are Coming
# 10859                                           Seconds
# 10860                               Carry On Screaming!
# ...

# %% [markdown]
# 3 Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
data.shape
# Out:
# (10866, 21)

# %%
print("Number of Rows", data.shape[0])
print("Number of Columns", data.shape[1])
# Out:
# Number of Rows 10866
# Number of Columns 21

# %% [markdown]
# 4 Getting Information About Our Dataset Like Total Number Rows , Total Number of Columns, Datatypes of Each Column And Memory

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %% [markdown]
# 5 Check Missing Values in The Dataset

# %%
print("Any missing value ", data.isnull().values.any())
# Out:
# Any missing value  True

# %%
data.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
per_missing =data.isnull().sum()*100/len(data)
per_missing
# Out:
# id                       0.000000
# imdb_id                  0.092030
# popularity               0.000000
# budget                   0.000000
# revenue                  0.000000
# original_title           0.000000
# cast                     0.699429
# homepage                72.979937
# director                 0.404933
# tagline                 25.989324
# keywords                13.740107
# overview                 0.036812
# runtime                  0.000000
# genres                   0.211669
# production_companies     9.479109
# release_date             0.000000
# vote_count               0.000000
# vote_average             0.000000
# release_year             0.000000
# budget_adj               0.000000
# revenue_adj              0.000000
# dtype: float64

# %% [markdown]
# 6 Drop All The Missing Values

# %%
data.dropna(axis=0)
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10724     668  tt0064757    1.778746    7000000    81974493
# 10759     948  tt0077651    1.198849     300000    70000000
# 10760    8469  tt0077975    1.157930    2700000   141000000
# 10817   13963  tt0077838    0.064029          0      321952
# 10819   16214  tt0077696    0.044675          0    78000000
#
#                         original_title  \
# 0                       Jurassic World
# 1                   Mad Max: Fury Road
# 2                            Insurgent
# 3         Star Wars: The Force Awakens
# 4                            Furious 7
# ...

# %% [markdown]
# 7 Check For Duplicate Data

# %%
dup_data=data.duplicated().any()
print("Are there any duplicate values?",dup_data)
# Out:
# Are there any duplicate values? True

# %%
data=data.drop_duplicates()
data
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %% [markdown]
# 8 Get Overall Statistics About The DataFrame

# %%
data.describe(include='all')
# Out:
#                    id    imdb_id    popularity        budget       revenue  \
# count    10865.000000      10855  10865.000000  1.086500e+04  1.086500e+04
# unique            NaN      10855           NaN           NaN           NaN
# top               NaN  tt0369610           NaN           NaN           NaN
# freq              NaN          1           NaN           NaN           NaN
# mean     66066.374413        NaN      0.646446  1.462429e+07  3.982690e+07
# std      92134.091971        NaN      1.000231  3.091428e+07  1.170083e+08
# min          5.000000        NaN      0.000065  0.000000e+00  0.000000e+00
# 25%      10596.000000        NaN      0.207575  0.000000e+00  0.000000e+00
# 50%      20662.000000        NaN      0.383831  0.000000e+00  0.000000e+00
# 75%      75612.000000        NaN      0.713857  1.500000e+07  2.400000e+07
# max     417859.000000        NaN     32.985763  4.250000e+08  2.781506e+09
#
# ...

# %% [markdown]
# 9 Display Title of The Movie Having Runtime >=180 Minutes

# %%
data.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
data[data['runtime']>=180] ['original_title']
# Out:
# 415                                     Show Me a Hero
# 559                                    Childhood's End
# 609      The Jinx: The Life and Deaths of Robert Durst
# 989                                   Olive Kitteridge
# 1077                                           Houdini
#                              ...
# 10674                                        Woodstock
# 10691                                   Doctor Zhivago
# 10716                     The Greatest Story Ever Told
# 10762                                  The Deer Hunter
# 10835                                 The Sand Pebbles
# Name: original_title, Length: 145, dtype: object

# %% [markdown]
# 10 In Which Year There Was The Highest Average Voting

# %%
data.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
data.groupby('release_year')['vote_count'].mean().sort_values(ascending=False)
# Out:
# release_year
# 2013    325.471927
# 2012    312.141156
# 2014    294.660000
# 2015    290.019078
# 2010    265.928425
# 2001    260.570248
# 2004    257.980456
# 2011    250.812963
# 2003    243.505338
# 1999    238.602679
# 2002    236.481203
# 2009    224.557223
# 1997    213.463542
# 2008    206.778226
# 2007    206.372146
# 1995    204.628571
# 1994    204.298913
# 2000    203.550661
# 2005    201.472527
# 1998    190.676190
# 2006    186.477941
# 1990    163.446970
# 1979    154.912281
# 1984    146.390476
# 1992    146.218045
# 1977    140.894737
# 1982    140.555556
# 1980    139.717949
# 1975    138.363636
# 1993    136.426966
# 1989    136.182482
# 1972    135.825000
# 1991    127.864662
# 1996    127.602941
# 1985    126.247706
# 1983    123.575000
# 1987    120.512000
# 1986    113.016529
# 1974    110.787234
# 1968    108.128205
# 1988    100.524138
# 1976    100.425532
# 1973     94.054545
# 1971     92.381818
# 1981     91.219512
# 1963     82.823529
# ...

# %%
sns.barplot(x='release_year', y='vote_count', data=data)
plt.title('Voting By Release Year')
plt.show()

# %% [markdown]
# 11 In Which Year There Was The Hightest Average Revenue?

# %%
data.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
data.groupby('release_year')['revenue_adj'].mean().sort_values(ascending=False)
# Out:
# release_year
# 1977    1.376362e+08
# 1967    1.205763e+08
# 1973    1.092939e+08
# 1965    9.057670e+07
# 1979    8.880802e+07
# 1975    8.817223e+07
# 1961    7.947167e+07
# 1970    7.674178e+07
# 1974    7.645280e+07
# 1997    7.538870e+07
# 1995    7.487098e+07
# 1992    7.101953e+07
# 1978    7.044251e+07
# 1982    6.858277e+07
# 2001    6.824115e+07
# 1990    6.720056e+07
# 2002    6.673644e+07
# 1999    6.636262e+07
# 1989    6.631404e+07
# 1976    6.530237e+07
# 1972    6.449502e+07
# 2003    6.385821e+07
# 2004    6.315163e+07
# 1983    6.314877e+07
# 2000    6.124336e+07
# 1998    6.047132e+07
# 1980    5.999930e+07
# 1993    5.898085e+07
# 1964    5.707603e+07
# 1994    5.672917e+07
# 1991    5.665942e+07
# 1996    5.664106e+07
# 1985    5.348319e+07
# 1987    5.315246e+07
# 1984    5.268644e+07
# 1981    5.190054e+07
# 2005    5.066509e+07
# 1986    4.936980e+07
# 1962    4.856238e+07
# 1988    4.755396e+07
# 1969    4.677888e+07
# 2007    4.660877e+07
# ...

# %%
sns.barplot(x='release_year', y='revenue_adj', data=data)
plt.title('Revenue By Release Year')
plt.show()

# %% [markdown]
# 12 Find The Average Rating For Each Director

# %%
data.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
data.groupby('director') ['vote_average'].mean().sort_values(ascending=False)
# Out:
# director
# Mark Cousins                            9.2
# Derek Frankowski                        8.8
# David Mallet                            8.7
# Martin Scorsese|Michael Henry Wilson    8.5
# James Payne                             8.5
#                                        ...
# Lawrence Kasanoff                       2.2
# Justin Russell                          2.2
# James Nguyen                            2.1
# Brett Kelly                             2.0
# Harold P. Warren                        1.5
# Name: vote_average, Length: 5067, dtype: float64

# %% [markdown]
# 13 Display Top 10 Length Movies Title and Runtime

# %%
data.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
top10_len=data.nlargest(10, 'runtime')[['original_title', 'runtime']].set_index('original_title')
top10_len
# Out:
#                                runtime
# original_title
# The Story of Film: An Odyssey      900
# Taken                              877
# Band of Brothers                   705
# Shoah                              566
# North and South, Book I            561
# Planet Earth                       550
# The Pacific                        540
# John Adams                         501
# Life                               500
# Generation Kill                    470

# %%
sns.barplot(x='runtime', y=top10_len.index, data=top10_len)
# Out:
# <Axes: xlabel='runtime', ylabel='original_title'>

# %% [markdown]
# 14 Display Number of Movies Per year

# %%
data.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
data['release_year'].value_counts()
# Out:
# release_year
# 2014    700
# 2013    659
# 2015    629
# 2012    588
# 2011    540
# 2009    533
# 2008    496
# 2010    489
# 2007    438
# 2006    408
# 2005    364
# 2004    307
# 2003    281
# 2002    266
# 2001    242
# 2000    227
# 1999    224
# 1998    210
# 1996    204
# 1997    192
# 1994    184
# 1993    178
# 1995    175
# 1988    145
# 1989    137
# 1991    133
# 1992    133
# 1990    132
# 1987    125
# 1986    121
# 1985    109
# 1984    105
# 1981     82
# 1982     81
# 1983     80
# 1980     78
# 1978     65
# 1977     57
# 1979     57
# 1973     55
# 1971     55
# 1976     47
# 1974     47
# 1966     46
# 1975     44
# 1964     42
# 1970     41
# 1967     40
# 1972     40
# 1968     39
# 1965     35
# 1963     34
# 1960     32
# 1962     32
# 1961     31
# 1969     31
# Name: count, dtype: int64

# %%
sns.countplot(x='release_year', data=data)
plt.title("Number of Movies Release Year")
plt.show()

# %% [markdown]
# 15 Find Most Popular Movie Title (Higest Revenue)

# %%
data.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
data[data['revenue'].max()==data['revenue']]['original_title']
# Out:
# 1386    Avatar
# Name: original_title, dtype: object

# %% [markdown]
# 16 Display Top 10 Highes Rated Movie Title And its Director

# %%
data.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
top10_len=data.nlargest(10, 'vote_average')[['original_title', 'vote_average','director']].set_index('original_title')
top10_len
# Out:
#                                                     vote_average  \
# original_title
# The Story of Film: An Odyssey                                9.2
# The Mask You Live In                                         8.9
# Black Mirror: White Christmas                                8.8
# Life Cycles                                                  8.8
# Pink Floyd: Pulse                                            8.7
# Opeth: In Live Concert At The Royal Albert Hall              8.6
# John Mayer: Where the Light Is Live in Los Angeles           8.5
# The Art of Flight                                            8.5
# Doctor Who: The Time of the Doctor                           8.5
# A Personal Journey with Martin Scorsese Through...           8.5
#
#                                                                                 director
# original_title
# The Story of Film: An Odyssey                                               Mark Cousins
# ...

# %%
sns.barplot(x='vote_average', y=top10_len.index, data=top10_len, hue='director', dodge=False)
plt.legend(bbox_to_anchor=(1.05,1),loc=2)

# %% [markdown]
# 17 Display Top 10 Highest Revenue Movie Title

# %%
data.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
top_10=data.nlargest(10,'revenue')[['original_title','revenue']].set_index('original_title')
top_10
# Out:
#                                                  revenue
# original_title
# Avatar                                        2781505847
# Star Wars: The Force Awakens                  2068178225
# Titanic                                       1845034188
# The Avengers                                  1519557910
# Jurassic World                                1513528810
# Furious 7                                     1506249360
# Avengers: Age of Ultron                       1405035767
# Harry Potter and the Deathly Hallows: Part 2  1327817822
# Frozen                                        1274219009
# Iron Man 3                                    1215439994

# %%
sns.barplot(x='revenue', y=top_10.index, data=top_10)
plt.title("Top 10 Highest Revenue Movies Title")
plt.show()

# %% [markdown]
# 18 Find Average Rating of Movies Year Wise

# %%
data.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
data.groupby('release_year')['vote_average'].mean().sort_values(ascending=False)
# Out:
# release_year
# 1973    6.703636
# 1972    6.535000
# 1971    6.420000
# 1970    6.417073
# 1974    6.395745
# 1975    6.390909
# 1968    6.379487
# 1961    6.374194
# 1962    6.343750
# 1976    6.340426
# 1963    6.329412
# 1960    6.325000
# 1979    6.308772
# 1967    6.242500
# 1982    6.241975
# 1964    6.211905
# 1965    6.194286
# 1985    6.177064
# 1981    6.165854
# 1980    6.160256
# 1977    6.147368
# 1978    6.130769
# 1987    6.128800
# 1966    6.128261
# 1992    6.081203
# 1989    6.070073
# 1995    6.056000
# 1993    6.050000
# 1999    6.032589
# 1991    6.014286
# 1986    6.004959
# 1984    6.003810
# 1990    5.993939
# 2010    5.992843
# 2004    5.988599
# 1997    5.988542
# 2002    5.973308
# 1983    5.971250
# 1998    5.970476
# 1988    5.965517
# 2007    5.964384
# 1969    5.961290
# 2011    5.958519
# 1994    5.942391
# 2006    5.941422
# 2003    5.930961
# 2008    5.930847
# 2014    5.920714
# 1996    5.900980
# 2001    5.896281
# 2015    5.885692
# ...

# %% [markdown]
# 19 Does Rating Affect The Revenue

# %%
data.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
sns.scatterplot(x="vote_average", y="revenue", data=data)
# Out:
# <Axes: xlabel='vote_average', ylabel='revenue'>

# %% [markdown]
# 20 Classify Movies Based on Ratings [Excellent, Good and Average]

# %%
data.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
def rating(rating):
    if rating>=7.0:
        return "Excellent"
    elif rating>=6.0:
        return "Good"
    else:
        return "Average"

# %%
data['rating_cat']=data['vote_average'].apply(rating)
data.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %% [markdown]
# 21 Count Number of Action Movies
